# %% [markdown]
# # Integration

# %%
from bunq.sdk.context.api_context import ApiContext
from bunq.sdk.context.bunq_context import BunqContext
from bunq import ApiEnvironmentType

# %%
api_context = ApiContext.restore("bunq_api_context.conf")
BunqContext.load_api_context(api_context)
# Out:
# ---------------------------------------------------------------------------
# BadRequestException                       Traceback (most recent call last)
# Cell In[85], line 2
#       1 api_context = ApiContext.restore("bunq_api_context.conf")
# ----> 2 BunqContext.load_api_context(api_context)
#
# File ~/Development/Bunq6_0/venv/lib/python3.11/site-packages/bunq/sdk/context/bunq_context.py:24, in BunqContext.load_api_context(cls, api_context)
#      19 cls._api_context = api_context
#      20 cls._user_context = UserContext(
#      21     api_context.session_context.user_id,
#      22     api_context.session_context.get_user_reference()
#      23 )
# ---> 24 cls._user_context.init_main_monetary_account()
#
# File ~/Development/Bunq6_0/venv/lib/python3.11/site-packages/bunq/sdk/context/user_context.py:47, in UserContext.init_main_monetary_account(self)
#      44 if self._user_payment_service_provider is not None:
#      45     return
# ---> 47 all_monetary_account = MonetaryAccountBankApiObject.list().value
#      49 for account in all_monetary_account:
#      50     if account.status == self._STATUS_ACTIVE:
#
# File ~/Development/Bunq6_0/venv/lib/python3.11/site-packages/bunq/sdk/model/generated/endpoint.py:21602, in MonetaryAccountBankApiObject.list(cls, params, custom_headers)
#   21600 api_client = ApiClient(cls._get_api_context())
#   21601 endpoint_url = cls._ENDPOINT_URL_LISTING.format(cls._determine_user_id())
# > 21602 response_raw = api_client.get(endpoint_url, params, custom_headers)
#   21604 return BunqResponseMonetaryAccountBankList.cast_from_bunq_response(
#   21605     cls._from_json_list(response_raw, cls._OBJECT_TYPE_GET)
#   21606 )
#
# File ~/Development/Bunq6_0/venv/lib/python3.11/site-packages/bunq/sdk/http/api_client.py:248, in ApiClient.get(self, uri_relative, params, custom_headers)
#     244 def get(self,
#     245         uri_relative: str,
#     246         params: Dict[str, str],
#     247         custom_headers: Dict[str, str]) -> BunqResponseRaw:
# --> 248     return self._request(
#     249         self.METHOD_GET,
#     250         uri_relative,
#     251         self.BYTES_EMPTY,
#     252         params,
#     253         custom_headers
#     254     )
#
# File ~/Development/Bunq6_0/venv/lib/python3.11/site-packages/bunq/sdk/http/api_client.py:131, in ApiClient._request(self, method, uri_relative, request_bytes, params, custom_headers)
#     118 all_headers = self._get_all_headers(
#     119     request_bytes,
#     120     custom_headers
#     121 )
#     123 response = requests.request(
#     124     method,
#     125     self._get_uri_full(uri_relative_with_params),
#    (...)    128     proxies={self.FIELD_PROXY_HTTPS: self._api_context.proxy_url},
#     129 )
# --> 131 self._assert_response_success(response)
#     133 if self._api_context.installation_context is not None:
#     134     security.validate_response(
#     135         self._api_context.installation_context.public_key_server,
#     136         response.status_code,
#     137         response.content,
#     138         response.headers
#     139     )
#
# File ~/Development/Bunq6_0/venv/lib/python3.11/site-packages/bunq/sdk/http/api_client.py:192, in ApiClient._assert_response_success(self, response)
#     186 """
#     187
#     188 :raise ApiException: When the response is not successful.
#     189 """
#     191 if response.status_code != self.STATUS_CODE_OK:
# --> 192     raise ExceptionFactory.create_exception_for_response(
#     193         response.status_code,
#     194         self._fetch_all_error_message(response),
#     195         self._fetch_response_id(response)
#     196     )
#
# BadRequestException: HTTP Response Code: 400
# The response id to help bunq debug: 875807ef-8835-4c9f-9d45-45cf5f10c01c
# Error message: User credentials are incorrect. Incorrect API key or IP address.

# %%
# Access the user context
user_context = BunqContext.user_context()

# Get the user ID
user_id = user_context.user_id  # 1880464

# Get the primary monetary account
primary_account = user_context.primary_monetary_account  # bunq.sdk.model.generated.endpoint.MonetaryAccountBankApiObject

primary_account.id_  # account id: 2108196

# %%
# Make a payment
PaymentApiObject.create(
    amount=AmountObject("1.00", "EUR"),
    counterparty_alias=PointerObject("EMAIL", "sugardaddy@bunq.com"),
    description="Payment for services"
).value
# Out:
# 25284574

# %%
from bunq.sdk.model.generated.endpoint import RequestInquiryApiObject
# Request a payment
RequestInquiryApiObject.create(
    AmountObject("10.00", "EUR"),
    PointerObject("EMAIL", "sugardaddy@bunq.com"),
    "Payment for services",
    allow_bunqme=False
).value
# Out:
# 1498264

# %%
from bunq.sdk.model.generated.endpoint import MonetaryAccountBankApiObject

# Get a monetary account
monetary_account = MonetaryAccountBankApiObject.get(2108196).value

# %%
monetary_account

# %%
monetary_account

print("Monetary account get", monetary_account.id_)
print("Monetary account get", monetary_account._daily_limit.value)
print("Monetary account get", monetary_account.currency)
print("Monetary account get", monetary_account.balance.value)
# Out:
# Monetary account get 2108196
# Monetary account get 5000.00
# Monetary account get EUR
# Monetary account get 0.00

# %%
from bunq.sdk.model.generated.endpoint import MonetaryAccountBankApiObject
from bunq.sdk.model.generated.endpoint import PaymentApiObject
from bunq import Pagination


# Create pagination
pagination = Pagination()
pagination.count = 10

# get a list of all accounts
monetary_accounts = MonetaryAccountBankApiObject.list(params=pagination.url_params_count_only).value

for account in monetary_accounts:
    print(f"Account ID: {account.id_}")
    print(f"Description: {account.description}")
    print(f"Balance: {account.balance.value} {account.balance.currency}")
    print(f"IBAN: {account.alias[0].value if account.alias else 'No IBAN'}")
    print("---")
# Out:
# Account ID: 2108196
# Description: Main
# Balance: 9.00 EUR
# IBAN: +31619157241
# ---
# Account ID: 2108197
# Description: General
# Balance: 6870.94 EUR
# IBAN: NL18BUNQ2090621923
# ---
# Account ID: 2108198
# Description: Home
# Balance: 0.00 EUR
# IBAN: NL45BUNQ2090633271
# ---
# Account ID: 2108199
# Description: Grocery
# Balance: 0.00 EUR
# IBAN: NL70BUNQ2090625546
# ---
# Account ID: 2108200
# Description: Travel
# Balance: 0.00 EUR
# IBAN: NL56BUNQ2090638796
# ---
# Account ID: 2108201
# Description: Subscriptions
# Balance: 0.00 EUR
# IBAN: NL91BUNQ2090634286
# ---
# Account ID: 2108202
# Description: Shopping
# Balance: 0.00 EUR
# IBAN: NL86BUNQ2090633697
# ---

# %%
# Create pagination
pagination = Pagination()
pagination.count = 10

# List payments
payments = PaymentApiObject.list(monetary_account_id=2108197, params=pagination.url_params_count_only).value

# Display payments
for payment in payments:
    print(f"ID: {payment.id_}")
    print(f"Amount: {payment.amount.value} {payment.amount.currency}")
    print(f"Description: {payment.description}")
    print(f"Created: {payment.created}")
    print("---")
# Out:
# ID: 25278524
# Amount: -11.14 EUR
# Description: KA Sloterdijk Amsterdam, NL
#
# Created: 2025-05-02 15:19:23.179669
# ---
# ID: 25278522
# Amount: -18.19 EUR
# Description: Albert Heijn 8636 Amsterdam, NL
#
# Created: 2025-05-02 15:19:22.951273
# ---
# ID: 25278520
# Amount: -18.71 EUR
# Description: UNIQLO EUROPE LTD Amsterdam, NL
#
# Created: 2025-05-02 15:19:22.757406
# ---
# ID: 25278518
# Amount: -19.22 EUR
# Description: Milkshake Festival Amsterdam, NL
#
# Created: 2025-05-02 15:19:22.566323
# ---
# ID: 25278516
# Amount: -13.27 EUR
# Description: Starbucks ASS 8907 Amsterdam, NL
#
# Created: 2025-05-02 15:19:22.361456
# ---
# ID: 25278514
# Amount: -18.35 EUR
# Description: Milkshake Festival Amsterdam, NL
#
# Created: 2025-05-02 15:19:22.171863
# ---
# ID: 25278512
# Amount: -17.30 EUR
# Description: McDonald's Kinkerstr Amsterdam, NL
#
# Created: 2025-05-02 15:19:21.938231
# ---
# ID: 25278511
# Amount: 6987.12 EUR
# Description: Salary 5 months since creation
# Created: 2025-05-01 15:19:21.734177
# ---

# %%
payments[0].
# Out:
# <bound method PaymentApiObject.create of <class 'bunq.sdk.model.generated.endpoint.PaymentApiObject'>>

# %%
payments
# Out:
# []

# %%
from bunq.sdk.context.api_context import ApiContext
from bunq.sdk.context.bunq_context import BunqContext
from bunq import ApiEnvironmentType
from bunq.sdk.model.generated.endpoint import MonetaryAccountBankApiObject, PaymentApiObject,BunqMeTabResultResponseApiObject,BunqMeTabApiObject, BunqMeTabEntryApiObject, BunqMeTabEntryApiObject
from bunq.sdk.model.generated.object_ import AmountObject, PointerObject, NotificationFilterObject
from bunq import Pagination
import time


# Get the user ID
user_id = user_context.user_id

print(user_id)

primary_account: MonetaryAccountBankApiObject = user_context.primary_monetary_account
print("monetary account", primary_account.id_)


# Create a payment
payment_id = PaymentApiObject.create(
    amount=AmountObject("1.00", "EUR"),
    counterparty_alias=PointerObject("EMAIL", "sugardaddy@bunq.com"),
    description="Payment for services"
).value

print(payment_id)

print(primary_account.balance.value)



# Getting a monetary account
#
# Id: 2098200
monetary_account = MonetaryAccountBankApiObject.get(2098200).value
print("Monetary account get", monetary_account.id_)
print("Monetary account get", monetary_account._daily_limit.value)
print("Monetary account get", monetary_account.currency)
print("Monetary account get", monetary_account.balance.value)

ma_list = MonetaryAccountBankApiObject.list().value

for ma in ma_list:
    print(ma.id_)


print("Update MA Object")
updated_ma = MonetaryAccountBankApiObject.update(
    2098200,
    daily_limit=AmountObject("1000.00", "EUR")
)

print("Updated monetary account", updated_ma)





# Create a URL notification filter for account mutations
notification_filter = NotificationFilterObject(category="MUTATION", notification_target="https://webhook.site/e467480a-0ac2-4c77-b26f-78cd6ced67cf")
all_notification_filter = [notification_filter]

print(all_notification_filter)
payment_id = PaymentApiObject.create(
    amount=AmountObject("1.00", "EUR"),
    counterparty_alias=PointerObject("EMAIL", "sugardaddy@bunq.com"),
    description="Payment for services"
).value

print(payment_id)



# Listing payments
print("Listing payments")
# # Create pagination
pagination = Pagination()
pagination.count = 10

# List payments
payments = PaymentApiObject.list(params=pagination.url_params_count_only).value

# Display payments
for payment in payments:
    print(f"ID: {payment.id_}")
    print(f"Amount: {payment.amount.value} {payment.amount.currency}")
    print(f"Description: {payment.description}")
    print("---")


# bunq.me tab
#

bunq_me_tab_entry = BunqMeTabEntryApiObject(
    amount_inquired=AmountObject("1.00", "EUR"),
    description="Payment for services",
    redirect_url="https://bunq.com"  # whatever URL you want to redirect to after
)

create_bunq_me_tab = BunqMeTabApiObject(bunqme_tab_entry=bunq_me_tab_entry).create(bunqme_tab_entry=bunq_me_tab_entry).value
get_bunq_me_tab = BunqMeTabApiObject(bunqme_tab_entry=bunq_me_tab_entry).get(create_bunq_me_tab).value

print(get_bunq_me_tab.bunqme_tab_share_url)
# Out:
# 1880464
# monetary account 2108196
# ---------------------------------------------------------------------------
# BadRequestException                       Traceback (most recent call last)
# Cell In[24], line 20
#      16 print("monetary account", primary_account.id_)
#      19 # Create a payment
# ---> 20 payment_id = PaymentApiObject.create(
#      21     amount=AmountObject("1.00", "EUR"),
#      22     counterparty_alias=PointerObject("EMAIL", "sugardaddy@bunq.com"),
#      23     description="Payment for services"
#      24 ).value
#      26 print(payment_id)
#      28 print(primary_account.balance.value)
#
# File ~/Development/Bunq6_0/venv/lib/python3.11/site-packages/bunq/sdk/model/generated/endpoint.py:2852, in PaymentApiObject.create(cls, amount, counterparty_alias, description, monetary_account_id, attachment, merchant_reference, allow_bunqto, custom_headers)
#    2850 request_bytes = request_map_string.encode()
#    2851 endpoint_url = cls._ENDPOINT_URL_CREATE.format(cls._determine_user_id(), cls._determine_monetary_account_id(monetary_account_id))
# -> 2852 response_raw = api_client.post(endpoint_url, request_bytes, custom_headers)
#    2854 return BunqResponseInt.cast_from_bunq_response(
#    2855     cls._process_for_id(response_raw)
#    2856 )
#
# File ~/Development/Bunq6_0/venv/lib/python3.11/site-packages/bunq/sdk/http/api_client.py:97, in ApiClient.post(self, uri_relative, request_bytes, custom_headers)
#      93 def post(self,
#      94          uri_relative: str,
#      95          request_bytes: bytes,
#      96          custom_headers: Dict[str, str]) -> BunqResponseRaw:
# ---> 97     return self._request(
#      98         self.METHOD_POST,
#      99         uri_relative,
#     100         request_bytes,
#     101         {},
#     102         custom_headers
#     103     )
#
# File ~/Development/Bunq6_0/venv/lib/python3.11/site-packages/bunq/sdk/http/api_client.py:131, in ApiClient._request(self, method, uri_relative, request_bytes, params, custom_headers)
#     118 all_headers = self._get_all_headers(
#     119     request_bytes,
#     120     custom_headers
#     121 )
#     123 response = requests.request(
#     124     method,
#     125     self._get_uri_full(uri_relative_with_params),
#    (...)    128     proxies={self.FIELD_PROXY_HTTPS: self._api_context.proxy_url},
#     129 )
# --> 131 self._assert_response_success(response)
#     133 if self._api_context.installation_context is not None:
#     134     security.validate_response(
#     135         self._api_context.installation_context.public_key_server,
#     136         response.status_code,
#     137         response.content,
#     138         response.headers
#     139     )
#
# File ~/Development/Bunq6_0/venv/lib/python3.11/site-packages/bunq/sdk/http/api_client.py:192, in ApiClient._assert_response_success(self, response)
#     186 """
#     187
#     188 :raise ApiException: When the response is not successful.
#     189 """
#     191 if response.status_code != self.STATUS_CODE_OK:
# --> 192     raise ExceptionFactory.create_exception_for_response(
#     193         response.status_code,
#     194         self._fetch_all_error_message(response),
#     195         self._fetch_response_id(response)
#     196     )
#
# BadRequestException: HTTP Response Code: 400
# The response id to help bunq debug: 44ce2c8f-7f00-42a8-aa8c-c9c7538ea7cd
# Error message: Account doesn't have enough money to complete the payment.
